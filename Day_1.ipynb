# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
print(np.exp(1))
print(np.pi)
# Out:
# 2.718281828459045
# 3.141592653589793

# %%
path = '/content/drive/MyDrive/Display_AI/seoul_temp.txt'
data = np.loadtxt(path, dtype='str')
print(data)
# Out:
# [['1954-01-01' '-7.8' '-2.4' '4.0']
#  ['1954-01-02' '-6.3' '-1.5' '2.0']
#  ['1954-01-03' '-2.6' '0.7' '3.9']
#  ...
#  ['2021-12-29' '-3.8' '0.4' '5.9']
#  ['2021-12-30' '-6.8' '-3.9' '0.2']
#  ['2021-12-31' '-8.8' '-6.7' '-3.9']]

# %%
print(data.shape)
y = data[:,2].astype(float)
print(y)
# Out:
# (24837, 4)
# [-2.4 -1.5  0.7 ...  0.4 -3.9 -6.7]

# %%
y = data[:,2].astype(float)
x = range(len(y))
plt.plot(x,y)
plt.xlabel('day')
plt.ylabel('average temp')
plt.title('average temperature in seoul')
plt.show()
